# %%
class MeraLR:

    def __init__(self):
        self.m = None
        self.b = None

    def fit(self, X_train, y_train):

      num = 0
      den = 0
      for i in range(X_train.shape[0]):

           num = num  +  ((X_train.iloc[i] -  X_train.mean())*(y_train.iloc[i] - y_train.mean()))      # finding the numerator for m
           den = den  +  ((X_train.iloc[i] -  X_train.mean())*(X_train.iloc[i] -  X_train.mean()))     # finding the denominator for m
      self.m = num/den
      self.b = y_train.mean() - (self.m * X_train.mean())

      print(self.m)
      print(self.b)


    def predict(self, X_test):

        print(X_test)
        return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e2b9102f-32ea-467c-9666-575f9ddf4180" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2b9102f-32ea-467c-9666-575f9ddf4180">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df =pd.read_csv('placement (2).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (160, 1)

# %%
X_test.shape
# Out:
# (40, 1)

# %% [markdown]
# we are getting the self made class into lr variable which we will fit and transform in train test and train it to predict

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y_train)
# Out:
# cgpa    0.557952
# dtype: float64
# cgpa   -0.896112
# dtype: float64

# %%
X_train
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [160 rows x 1 columns]

# %%
Y_pred=lr.predict(X_test)
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
X_test.iloc[0]
# Out:
# cgpa    8.58
# Name: 112, dtype: float64

# %%
print(lr.predict(X_test.iloc[0]))
# Out:
# cgpa    8.58
# Name: 112, dtype: float64
# cgpa    3.891116
# dtype: float64

# %%
X_test.iloc[2]
# Out:
# cgpa    5.88
# Name: 182, dtype: float64

# %%
print(lr.predict(X_test.iloc[2]))
# Out:
# cgpa    5.88
# Name: 182, dtype: float64
# cgpa    2.384646
# dtype: float64
